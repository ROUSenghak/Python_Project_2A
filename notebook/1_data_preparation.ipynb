# %% [markdown]
# ## Data preparation: combining electricity and weather data

# %%
import pandas as pd
import numpy as np
import time
import os
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from datetime import datetime

# %% [markdown]
# ### Regional electricity data (RTE)

# %%
# Defines RTE folder paths for each region
folder_path = {"Auvergne":"../data/RTE/Auvergne",
                "Bourgone":"../data/RTE/Bourgogne",
                "Bretagne":"../data/RTE/Bretagne",
                "Centre_Val":"../data/RTE/Centre_Val",
                "Grand_est":"../data/RTE/Grand_est",
                "Hauts-de-france":"../data/RTE/Hauts_de_france",
                "Île-de-France":"../data/RTE/Ile-de-france",
                "Normandie":"../data/RTE/Normandie",
                "Nouvelle-Aquitaine":"../data/RTE/Nouvelle_aquitaine",
                "Occitanie":"../data/RTE/Occitaine",
                "Pays-de-la-loire":"../data/RTE/Pays_de_la_loire",
                "Provence-Alpes-Côte d'Azur":"../data/RTE/PACA"}

# %%
# Builds the list of all RTE Excel files across regions
paths_file = []
for ele in folder_path.items():
    for xls in os.listdir(ele[1]):
        if xls.endswith(".xls"):
            file_xls = os.path.join(ele[1],xls)
            paths_file.append(file_xls)
paths_file
# Out:
# ['../data/RTE/Auvergne/eCO2mix_RTE_Auvergne-Rhone-Alpes_Annuel-Definitif_2020.xls',
#  '../data/RTE/Auvergne/eCO2mix_RTE_Auvergne-Rhone-Alpes_Annuel-Definitif_2021.xls',
#  '../data/RTE/Auvergne/eCO2mix_RTE_Auvergne-Rhone-Alpes_Annuel-Definitif_2023.xls',
#  '../data/RTE/Auvergne/eCO2mix_RTE_Auvergne-Rhone-Alpes_Annuel-Definitif_2022.xls',
#  '../data/RTE/Auvergne/eCO2mix_RTE_Auvergne-Rhone-Alpes_Annuel-Definitif_2024.xls',
#  '../data/RTE/Bourgogne/eCO2mix_RTE_Bourgogne-Franche-Comt‚_Annuel-Definitif_2023.xls',
#  '../data/RTE/Bourgogne/eCO2mix_RTE_Bourgogne-Franche-Comt‚_Annuel-Definitif_2022.xls',
#  '../data/RTE/Bourgogne/eCO2mix_RTE_Bourgogne-Franche-Comt‚_Annuel-Definitif_2020.xls',
#  '../data/RTE/Bourgogne/eCO2mix_RTE_Bourgogne-Franche-Comt‚_Annuel-Definitif_2021.xls',
#  '../data/RTE/Bourgogne/eCO2mix_RTE_Bourgogne-Franche-Comt‚_Annuel-Definitif_2024.xls',
#  '../data/RTE/Bretagne/eCO2mix_RTE_Bretagne_Annuel-Definitif_2022.xls',
#  '../data/RTE/Bretagne/eCO2mix_RTE_Bretagne_Annuel-Definitif_2023.xls',
#  '../data/RTE/Bretagne/eCO2mix_RTE_Bretagne_Annuel-Definitif_2021.xls',
#  '../data/RTE/Bretagne/eCO2mix_RTE_Bretagne_Annuel-Definitif_2020.xls',
#  '../data/RTE/Bretagne/eCO2mix_RTE_Bretagne_Annuel-Definitif_2024.xls',
#  '../data/RTE/Centre_Val/eCO2mix_RTE_Centre-Val-de-Loire_Annuel-Definitif_2023.xls',
#  '../data/RTE/Centre_Val/eCO2mix_RTE_Centre-Val-de-Loire_Annuel-Definitif_2022.xls',
#  '../data/RTE/Centre_Val/eCO2mix_RTE_Centre-Val-de-Loire_Annuel-Definitif_2020.xls',
#  '../data/RTE/Centre_Val/eCO2mix_RTE_Centre-Val-de-Loire_Annuel-Definitif_2021.xls',
#  '../data/RTE/Centre_Val/eCO2mix_RTE_Centre-Val-de-Loire_Annuel-Definitif_2024.xls',
#  '../data/RTE/Grand_est/eCO2mix_RTE_Grand-Est_Annuel-Definitif_2023.xls',
#  '../data/RTE/Grand_est/eCO2mix_RTE_Grand-Est_Annuel-Definitif_2022.xls',
#  '../data/RTE/Grand_est/eCO2mix_RTE_Grand-Est_Annuel-Definitif_2020.xls',
#  '../data/RTE/Grand_est/eCO2mix_RTE_Grand-Est_Annuel-Definitif_2021.xls',
#  '../data/RTE/Grand_est/eCO2mix_RTE_Grand-Est_Annuel-Definitif_2024.xls',
#  '../data/RTE/Hauts_de_france/eCO2mix_RTE_Hauts-de-France_Annuel-Definitif_2024.xls',
#  '../data/RTE/Hauts_de_france/eCO2mix_RTE_Hauts-de-France_Annuel-Definitif_2020.xls',
#  '../data/RTE/Hauts_de_france/eCO2mix_RTE_Hauts-de-France_Annuel-Definitif_2021.xls',
#  '../data/RTE/Hauts_de_france/eCO2mix_RTE_Hauts-de-France_Annuel-Definitif_2023.xls',
#  '../data/RTE/Hauts_de_france/eCO2mix_RTE_Hauts-de-France_Annuel-Definitif_2022.xls',
#  '../data/RTE/Ile-de-france/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2023.xls',
#  '../data/RTE/Ile-de-france/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2022.xls',
#  '../data/RTE/Ile-de-france/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2020.xls',
#  '../data/RTE/Ile-de-france/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2021.xls',
#  '../data/RTE/Ile-de-france/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2024.xls',
#  '../data/RTE/Normandie/eCO2mix_RTE_Normandie_Annuel-Definitif_2024.xls',
#  '../data/RTE/Normandie/eCO2mix_RTE_Normandie_Annuel-Definitif_2022.xls',
#  '../data/RTE/Normandie/eCO2mix_RTE_Normandie_Annuel-Definitif_2023.xls',
#  '../data/RTE/Normandie/eCO2mix_RTE_Normandie_Annuel-Definitif_2021.xls',
#  '../data/RTE/Normandie/eCO2mix_RTE_Normandie_Annuel-Definitif_2020.xls',
#  '../data/RTE/Nouvelle_aquitaine/eCO2mix_RTE_Nouvelle-Aquitaine_Annuel-Definitif_2024.xls',
#  '../data/RTE/Nouvelle_aquitaine/eCO2mix_RTE_Nouvelle-Aquitaine_Annuel-Definitif_2021.xls',
#  '../data/RTE/Nouvelle_aquitaine/eCO2mix_RTE_Nouvelle-Aquitaine_Annuel-Definitif_2020.xls',
#  '../data/RTE/Nouvelle_aquitaine/eCO2mix_RTE_Nouvelle-Aquitaine_Annuel-Definitif_2022.xls',
#  '../data/RTE/Nouvelle_aquitaine/eCO2mix_RTE_Nouvelle-Aquitaine_Annuel-Definitif_2023.xls',
#  '../data/RTE/Occitaine/eCO2mix_RTE_Occitanie_Annuel-Definitif_2022.xls',
#  '../data/RTE/Occitaine/eCO2mix_RTE_Occitanie_Annuel-Definitif_2023.xls',
#  '../data/RTE/Occitaine/eCO2mix_RTE_Occitanie_Annuel-Definitif_2021.xls',
#  '../data/RTE/Occitaine/eCO2mix_RTE_Occitanie_Annuel-Definitif_2020.xls',
#  '../data/RTE/Occitaine/eCO2mix_RTE_Occitanie_Annuel-Definitif_2024.xls',
#  '../data/RTE/Pays_de_la_loire/eCO2mix_RTE_Pays-de-la-Loire_Annuel-Definitif_2024.xls',
#  '../data/RTE/Pays_de_la_loire/eCO2mix_RTE_Pays-de-la-Loire_Annuel-Definitif_2020.xls',
#  '../data/RTE/Pays_de_la_loire/eCO2mix_RTE_Pays-de-la-Loire_Annuel-Definitif_2021.xls',
#  '../data/RTE/Pays_de_la_loire/eCO2mix_RTE_Pays-de-la-Loire_Annuel-Definitif_2023.xls',
#  '../data/RTE/Pays_de_la_loire/eCO2mix_RTE_Pays-de-la-Loire_Annuel-Definitif_2022.xls',
#  '../data/RTE/PACA/eCO2mix_RTE_PACA_Annuel-Definitif_2024.xls',
#  '../data/RTE/PACA/eCO2mix_RTE_PACA_Annuel-Definitif_2021.xls',
#  '../data/RTE/PACA/eCO2mix_RTE_PACA_Annuel-Definitif_2020.xls',
#  '../data/RTE/PACA/eCO2mix_RTE_PACA_Annuel-Definitif_2022.xls',
#  '../data/RTE/PACA/eCO2mix_RTE_PACA_Annuel-Definitif_2023.xls']

# %%
# Merging all RTE csv file
dfs = []
for file in paths_file:
    df = pd.read_csv(file, sep='\t', encoding='latin-1')
    dfs.append(df)
df_ele = pd.concat(dfs, ignore_index=True)
# Out:
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,18,20,25,26,28,30,32,37,38,40,44,47,51,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,17,20,21,23,29,32,33,35,47,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,24,27,36,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,17,18,23,24,25,27,29,30,35,36,37,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,18,22,23,30,34,35,41,42,47,48,49,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,21,23,24,33,35,36,42,46,49,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,18,20,21,22,24,30,32,33,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,19,20,22,23,27,31,32,34,35,39,46,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,17,20,26,27,29,32,38,39,43,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,17,25,28,29,37,40,43,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,19,20,24,25,31,32,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')
# /var/folders/tl/8bjdw3ds0tq7qbypyvcxvgyc0000gn/T/ipykernel_46116/906569633.py:4: DtypeWarning: Columns (12,13,14,15,17,26,29,38,44,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='latin-1')

# %%
df_ele.shape
# Out:
# (2104764, 389)

# %%
df_ele.head(10)
# Out:
#               Périmètre               Nature        Date Heures  Consommation  \
# 0  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:00        8911.0
# 1  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:15           NaN
# 2  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:30        8814.0
# 3  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:45           NaN
# 4  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:00        8589.0
# 5  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:15           NaN
# 6  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:30        8575.0
# 7  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:45           NaN
# 8  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  02:00        8560.0
# 9  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  02:15           NaN
#
#    Thermique Nucléaire  Eolien  Solaire  Hydraulique  ...  \
# 0      220.0   11556.0    41.0      0.0       3663.0  ...
# 1        NaN       NaN     NaN      NaN          NaN  ...
# 2      221.0   11555.0    38.0      0.0       3962.0  ...
# 3        NaN       NaN     NaN      NaN          NaN  ...
# 4      221.0   11439.0    34.0      0.0       3840.0  ...
# 5        NaN       NaN     NaN      NaN          NaN  ...
# 6      221.0   11618.0    38.0      0.0       3786.0  ...
# 7        NaN       NaN     NaN      NaN          NaN  ...
# 8      223.0   11663.0    38.0      0.0       3382.0  ...
# 9        NaN       NaN     NaN      NaN          NaN  ...
#
#   Flux physiques Luxembourg vers PACA  Flux physiques Royaume-Uni vers PACA  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
# 5                                 NaN                                   NaN
# 6                                 NaN                                   NaN
# 7                                 NaN                                   NaN
# 8                                 NaN                                   NaN
# 9                                 NaN                                   NaN
#
#    Flux physiques Suisse vers PACA Flux physiques de PACA vers Allemagne  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                              NaN                                   NaN
# 5                              NaN                                   NaN
# 6                              NaN                                   NaN
# 7                              NaN                                   NaN
# 8                              NaN                                   NaN
# 9                              NaN                                   NaN
#
#   Flux physiques de PACA vers Belgique Flux physiques de PACA vers Espagne  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# 5                                  NaN                                 NaN
# 6                                  NaN                                 NaN
# 7                                  NaN                                 NaN
# 8                                  NaN                                 NaN
# 9                                  NaN                                 NaN
#
#   Flux physiques de PACA vers Italie Flux physiques de PACA vers Luxembourg  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
# 5                                NaN                                    NaN
# 6                                NaN                                    NaN
# 7                                NaN                                    NaN
# 8                                NaN                                    NaN
# 9                                NaN                                    NaN
#
#   Flux physiques de PACA vers Royaume-Uni Flux physiques de PACA vers Suisse
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# 5                                     NaN                                NaN
# 6                                     NaN                                NaN
# 7                                     NaN                                NaN
# 8                                     NaN                                NaN
# 9                                     NaN                                NaN
#
# [10 rows x 389 columns]

# %%
feauture = ['Périmètre','Nature','Date','Heures','Consommation']
df_con = df_ele[feauture].copy()

# %% [markdown]
# ### Checking missing values in RTE data

# %%
df_con.isnull().sum()
# Out:
# Périmètre             0
# Nature               60
# Date                 60
# Heures               60
# Consommation    1052412
# dtype: int64

# %%
sns.heatmap(df_con.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### Distribution of electricity consumption before dropping missing values

# %%
plt.figure(figsize=(10, 6))
df_con["Consommation"].hist(bins=30)
plt.title("Distribution of electricity consumption before dropping missing values")
plt.xlabel("Electricity consumption (MWh)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Drop missing value

# %%
df_con = df_con.dropna()
df_ele = df_con.copy()

# %% [markdown]
# ### Distribution of electricity consumption after dropping missing values

# %%
plt.figure(figsize=(10, 6))
df_con["Consommation"].hist(bins=30)
plt.title("Distribution of electricity consumption after dropping missing values")
plt.xlabel("Electricity consumption (MWh)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Checking missing values in the cleaned dataset

# %%
sns.heatmap(df_con.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Comment:
# `Consommation` is systematically missing at fixed times (:15, :45), so these rows are structurally empty which is not real observations. <br>
# After dropping them, the histogram keeps the same right-skewed shape, meaning the overall distribution of electricity consumption is **unchanged**. we only removed rows with no valid value.

# %%
df_ele['Datetime'] = pd.to_datetime(
    df_ele['Date'].astype(str) + ' ' + df_ele['Heures'].astype(str),
    errors='coerce'
)

# %%
df_ele.head()
# Out:
#               Périmètre               Nature        Date Heures  Consommation  \
# 0  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:00        8911.0
# 2  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  00:30        8814.0
# 4  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:00        8589.0
# 6  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  01:30        8575.0
# 8  Auvergne-Rhône-Alpes  Données définitives  2020-01-01  02:00        8560.0
#
#              Datetime
# 0 2020-01-01 00:00:00
# 2 2020-01-01 00:30:00
# 4 2020-01-01 01:00:00
# 6 2020-01-01 01:30:00
# 8 2020-01-01 02:00:00

# %%
df_ele.shape
# Out:
# (1052352, 6)

# %%
# Aggregate half hourly RTE data to daily consumption per region
df_ele = df_ele.set_index('Datetime')
df_ele_daily = (
       df_ele.groupby("Périmètre", group_keys=False).resample('D')
           .agg({'Consommation': 'sum',
                  'Périmètre': 'first',
                 'Nature': 'first'})
           .reset_index()
)

# %%
df_ele_daily
# Out:
#         Datetime  Consommation             Périmètre               Nature
# 0     2020-01-01      403787.0  Auvergne-Rhône-Alpes  Données définitives
# 1     2020-01-02      443531.0  Auvergne-Rhône-Alpes  Données définitives
# 2     2020-01-03      434626.0  Auvergne-Rhône-Alpes  Données définitives
# 3     2020-01-04      395169.0  Auvergne-Rhône-Alpes  Données définitives
# 4     2020-01-05      400169.0  Auvergne-Rhône-Alpes  Données définitives
# ...          ...           ...                   ...                  ...
# 21919 2024-12-27      181429.0      Pays-de-la-Loire  Données consolidées
# 21920 2024-12-28      171307.0      Pays-de-la-Loire  Données consolidées
# 21921 2024-12-29      169980.0      Pays-de-la-Loire  Données consolidées
# 21922 2024-12-30      185431.0      Pays-de-la-Loire  Données consolidées
# 21923 2024-12-31      176371.0      Pays-de-la-Loire  Données consolidées
#
# [21924 rows x 4 columns]

# %%
df_ele_daily['Périmètre'].count
# Out:
# <bound method Series.count of 0        Auvergne-Rhône-Alpes
# 1        Auvergne-Rhône-Alpes
# 2        Auvergne-Rhône-Alpes
# 3        Auvergne-Rhône-Alpes
# 4        Auvergne-Rhône-Alpes
#                  ...
# 21919        Pays-de-la-Loire
# 21920        Pays-de-la-Loire
# 21921        Pays-de-la-Loire
# 21922        Pays-de-la-Loire
# 21923        Pays-de-la-Loire
# Name: Périmètre, Length: 21924, dtype: object>

# %%
df_ele_daily.columns
# Out:
# Index(['Datetime', 'Consommation', 'Périmètre', 'Nature'], dtype='object')

# %% [markdown]
# ## Weather data (NASA POWER)

# %%
# Imports functions to download NASA POWER weather data
import sys
sys.path.append("..") 
from scripts.get_data import fetch_power, fetch_region_weather_mean

# %%
# Defines time range and list of weather variables to download from NASA POWER
START, END = 2020, 2024            
TEMPORAL = "daily"                  
PARAMS = [
    # precipitation & humidity
    "PRECTOTCORR","RH2M","QV2M",
    # temperature (2m)
    "T2M","T2M_MAX","T2M_MIN","T2M_RANGE",
    # wind (2m,10m), direction (10m)
    "WS2M","WS10M","WD10M",
    # radiation (shortwave, all-sky, clear-sky)
    "ALLSKY_SFC_SW_DWN","CLRSKY_SFC_SW_DWN",
    # pressure
    "PS",
    # soil moisture 
    "GWETTOP","GWETROOT"
]

# %%
# region France (INSEE, name, lat, lon)
Regions = [
    ("83", "Auvergne-Rhône-Alpes", 45.2968119, 4.6604809),
    ("27", "Bourgogne-Franche-Comté", 47.118711, 4.9691044),
    ("53", "Bretagne", 48.2640845, -2.9202408),
    ("24", "Centre-Val de Loire", 47.5490251, 1.7324062),
    ("44", "Grand-Est", 48.4845157, 6.113035),
    ("32", "Hauts-de-France", 50.1024606, 2.7247515),
    ("11", "Ile-de-France", 48.6443057, 2.7537863),
    ("28", "Normandie", 49.0677708, 0.3138532),
    ("75", "Nouvelle-Aquitaine", 45.4039367, 0.3756199),
    ("76", "Occitanie", 43.6487851, 2.3435684),
    ("52", "Pays-de-la-Loire", 47.6594864, -0.8186143),
    ("93", "PACA", 44.0580563, 6.0638506),
]

# %%
REGION_POINTS = {
    "Auvergne-Rhône-Alpes": [
        ("center", 45.7500, 4.8500),   # Lyon 
        ("north",  46.2050, 5.2280),   # Bourg-en-Bresse 
        ("south",  44.9330, 4.8920),   # Valence 
        ("east",   45.8990, 6.1290),   # Annecy 
        ("west",   45.7830, 3.0830),   # Clermont-Ferrand 
    ],

    "Bourgogne-Franche-Comté": [
        ("center", 47.3220, 5.0410),   # Dijon 
        ("north",  47.7990, 3.5730),   # Auxerre 
        ("south",  46.3060, 4.8280),   # Mâcon 
        ("east",   47.2380, 6.0240),   # Besançon 
        ("west",   46.9890, 3.1590),   # Nevers 
    ],
    "Bretagne": [
        ("center", 48.1170, -1.6780),  # Rennes
        ("north",  48.5150, -2.7650),  # Saint-Brieuc
        ("south",  47.6580, -2.7600),  # Vannes 
        ("east",   48.3530, -1.1990),  # Fougères 
        ("west",   48.3900, -4.4860),  # Brest 
    ],

    "Centre-Val de Loire": [
        ("center", 47.9020, 1.9090),   # Orléans 
        ("north",  48.4470, 1.4890),   # Chartres 
        ("south",  46.8100, 1.6930),   # Châteauroux
        ("east",   47.5930, 1.3290),   # Blois 
        ("west",   47.3940, 0.6848),   # Tours 
    ],

    "Grand-Est": [
        ("center", 48.6930, 6.1830),   # Nancy 
        ("north",  49.7680, 4.7240),   # Charleville-Mézières 
        ("south",  47.7500, 7.3350),   # Mulhouse 
        ("east",   48.5730, 7.7520),   # Strasbourg 
        ("west",   49.2580, 4.0310),   # Reims 
    ],

    "Hauts-de-France": [
        ("center", 49.8940, 2.3000),   # Amiens 
        ("north",  51.0380, 2.3770),   # Dunkerque 
        ("south",  49.4300, 2.0830),   # Beauvais 
        ("east",   50.3570, 3.5240),   # Valenciennes 
        ("west",   50.7260, 1.6150),   # Boulogne-sur-Mer 
    ],

    "Ile-de-France": [
        ("center", 48.8566, 2.3522),   # Paris 
        ("north",  49.0360, 2.0630),   # Cergy 
        ("south",  48.6290, 2.4410),   # Évry-Courcouronnes 
        ("east",   48.9600, 2.8880),   # Meaux
        ("west",   48.8049, 2.1204),   # Versailles 
    ],

    "Normandie": [
        ("center", 49.1830, -0.3690),  # Caen 
        ("north",  49.9220, 1.0770),   # Dieppe 
        ("south",  48.4310, 0.0930),   # Alençon
        ("east",   49.0270, 1.1510),   # Évreux 
        ("west",   49.6390, -1.6210),  # Cherbourg-en-Cotentin 
    ],

    "Nouvelle-Aquitaine": [
        ("center", 45.6480, 0.1560),   # Angoulême 
        ("north",  46.5800, 0.3400),   # Poitiers 
        ("south",  43.2950, -0.3708),  # Pau 
        ("east",   45.8336, 1.2611),   # Limoges 
        ("west",   44.8378, -0.5792),  # Bordeaux 
    ],

    "Occitanie": [
        ("center", 43.6045, 1.4440),   # Toulouse 
        ("north",  44.3500, 2.5800),   # Rodez 
        ("south",  42.6880, 2.8940),   # Perpignan 
        ("east",   43.6108, 3.8767),   # Montpellier 
        ("west",   43.2330, 0.0830),   # Tarbes 
    ],

    "Pays-de-la-Loire": [
        ("center", 47.4780, -0.5630),  # Angers
        ("north",  48.0730, -0.7730),  # Laval 
        ("south",  46.6700, -1.4260),  # La Roche-sur-Yon 
        ("east",   48.0077, 0.1984),   # Le Mans
        ("west",   47.2184, -1.5536),  # Nantes 
    ],

    "PACA": [
        ("center", 43.5297, 5.4470),   # Aix-en-Provence 
        ("north",  44.5590, 6.0799),   # Gap 
        ("south",  43.1242, 5.9280),   # Toulon 
        ("east",   43.7102, 7.2620),   # Nice
        ("west",   43.9493, 4.8055),   # Avignon
    ],
}

# %%
all_regions_weather = []
for insee, name, lat, lon in Regions:
    print("Fetching region:", name)
    df_reg = fetch_region_weather_mean(name, START, END, temporal=TEMPORAL,REGION_POINTS=REGION_POINTS,PARAMS=PARAMS)
    all_regions_weather.append(df_reg)
df_weather_regions = pd.concat(all_regions_weather, ignore_index=True)
df_weather_regions.rename(columns={"date": "Datetime"}, inplace=True)
# Out:
# Fetching region: Auvergne-Rhône-Alpes
# Fetching region: Bourgogne-Franche-Comté
# Fetching region: Bretagne
# Fetching region: Centre-Val de Loire
# Fetching region: Grand-Est
# Fetching region: Hauts-de-France
# Fetching region: Ile-de-France
# Fetching region: Normandie
# Fetching region: Nouvelle-Aquitaine
# Fetching region: Occitanie
# Fetching region: Pays-de-la-Loire
# Fetching region: PACA

# %%
df_weather_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21924 entries, 0 to 21923
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Datetime           21924 non-null  datetime64[ns]
#  1   year               21924 non-null  int64
#  2   month              21924 non-null  int64
#  3   day                21924 non-null  int64
#  4   Regions            21924 non-null  object
#  5   ALLSKY_SFC_SW_DWN  21924 non-null  float64
#  6   CLRSKY_SFC_SW_DWN  21924 non-null  float64
#  7   GWETROOT           21924 non-null  float64
#  8   GWETTOP            21924 non-null  float64
#  9   PRECTOTCORR        21924 non-null  float64
#  10  PS                 21924 non-null  float64
#  11  QV2M               21924 non-null  float64
#  12  RH2M               21924 non-null  float64
#  13  T2M                21924 non-null  float64
#  14  T2M_MAX            21924 non-null  float64
#  15  T2M_MIN            21924 non-null  float64
#  16  T2M_RANGE          21924 non-null  float64
#  17  WD10M              21924 non-null  float64
#  18  WS10M              21924 non-null  float64
#  19  WS2M               21924 non-null  float64
# dtypes: datetime64[ns](1), float64(15), int64(3), object(1)
# memory usage: 3.3+ MB

# %% [markdown]
# ## Map of weather sampling points (5 subpoints per region)

# %%
# loads regions polygons
regions_url = "https://france-geojson.gregoiredavid.fr/repo/regions.geojson"
gdf_regions = gpd.read_file(regions_url)
gdf_regions.head()

# %%
# Flattens to a DataFrame
rows = []
for reg, pts in REGION_POINTS.items():
    for label, lat, lon in pts:
        rows.append({"region_key": reg, "label": label, "lat": lat, "lon": lon})

df_pts = pd.DataFrame(rows)

# Turns into GeoDataFrame
gdf_points = gpd.GeoDataFrame(
    df_pts,
    geometry=gpd.points_from_xy(df_pts["lon"], df_pts["lat"]),
    crs="EPSG:4326",
)

# %%
# Shows name on the plot 
name_map = {
    "Auvergne-Rhône-Alpes": "Auvergne-Rhône-Alpes",
    "Bourgogne-Franche-Comté": "Bourgogne-Franche-Comté",
    "Bretagne": "Bretagne",
    "Centre-Val de Loire": "Centre-Val de Loire",
    "Grand-Est": "Grand Est",
    "Hauts-de-France": "Hauts-de-France",
    "Ile-de-France": "Île-de-France",
    "Normandie": "Normandie",
    "Nouvelle-Aquitaine": "Nouvelle-Aquitaine",
    "Occitanie": "Occitanie",
    "Pays-de-la-Loire": "Pays de la Loire",
    "PACA": "Provence-Alpes-Côte d'Azur",
}
gdf_regions = gdf_regions[gdf_regions["nom"].isin(name_map.values())].copy()
reverse_map = {v: k for k, v in name_map.items()}
gdf_regions["region_key"] = gdf_regions["nom"].map(reverse_map)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plots regions with a different color per region
gdf_regions.plot(
    column="region_key",
    categorical=True,
    legend=True,
    edgecolor="black",
    linewidth=0.7,
    alpha=0.3,
    ax=ax,
)

# Plots points and colors 
gdf_points.plot(
    ax=ax,
    column="region_key",
    categorical=True,
    markersize=40,
    edgecolor="black",
    legend=False,
)
# adds label
for _, row in gdf_points.iterrows():
    ax.text(
        row.geometry.x + 0.05,
        row.geometry.y + 0.05,
        row["label"][0].upper(),  
        fontsize=5,
        ha="center",
    )
ax.set_title("Weather Data Locations by French Region", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---------

# %% [markdown]
# ## Merge daily electricity data with regional weather data

# %%
df_weather = df_weather_regions.copy()
df_weather.head(2)

# %%
# Rename columns
df_weather.rename(columns={"date":"Datetime","department":"Regions"}, inplace=True)
df_ele_daily.rename(columns={"Périmètre":"Regions"},inplace= True)

# %% [markdown]
# ### Joining electricity and weather data by region and datetime

# %%
df_weather['Datetime'] = pd.to_datetime(df_weather['Datetime'])
df_ele_daily['Datetime'] = pd.to_datetime(df_ele_daily['Datetime'])
# Merges on Datetime and Regions
df_final = pd.merge(
    df_ele_daily,
    df_weather,
    on=['Datetime', 'Regions'],
    how='inner'
)

# %%
df_final.head()
