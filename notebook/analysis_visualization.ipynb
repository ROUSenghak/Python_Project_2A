# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/onyxia/work/.env/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from plotly) (2.11.0)
# Requirement already satisfied: packaging in /home/onyxia/work/.env/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
df = pd.read_csv("../data/temp_electricity.csv")

# %%
df.head()
# Out:
#      Datetime  Consommation               Regions               Nature  year  \
# 0  2020-01-01      403787.0  Auvergne-Rhône-Alpes  Données définitives  2020
# 1  2020-01-02      443531.0  Auvergne-Rhône-Alpes  Données définitives  2020
# 2  2020-01-03      434626.0  Auvergne-Rhône-Alpes  Données définitives  2020
# 3  2020-01-04      395169.0  Auvergne-Rhône-Alpes  Données définitives  2020
# 4  2020-01-05      400169.0  Auvergne-Rhône-Alpes  Données définitives  2020
#
#    month  day  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  GWETROOT  ...  QV2M  \
# 0      1    1               5.39               6.80      0.68  ...  4.17
# 1      1    2               4.78               6.45      0.68  ...  4.41
# 2      1    3               3.80               6.38      0.68  ...  5.00
# 3      1    4               3.91               6.99      0.68  ...  4.76
# 4      1    5               5.85               7.13      0.67  ...  3.96
#
#     RH2M   T2M  T2M_MAX  T2M_MIN  T2M_RANGE  WD10M  WS10M  WS2M  insee_dep
# 0  96.11  0.81     5.26    -1.36       6.62  314.6   1.44  0.82         83
# 1  92.78  2.44     8.35    -0.89       9.24  200.2   3.64  2.26         83
# 2  93.72  3.94     8.16     1.49       6.67  246.6   3.21  1.91         83
# 3  94.68  3.18     5.62    -0.64       6.26  335.6   4.34  2.77         83
# 4  93.92  0.77     4.06    -1.25       5.31  354.9   3.75  2.43         83
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Datetime', 'Consommation', 'Regions', 'Nature', 'year', 'month', 'day',
#        'ALLSKY_SFC_SW_DWN', 'CLRSKY_SFC_SW_DWN', 'GWETROOT', 'GWETTOP',
#        'PRECTOTCORR', 'PS', 'QV2M', 'RH2M', 'T2M', 'T2M_MAX', 'T2M_MIN',
#        'T2M_RANGE', 'WD10M', 'WS10M', 'WS2M', 'insee_dep'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21924 entries, 0 to 21923
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Datetime           21924 non-null  object
#  1   Consommation       21924 non-null  float64
#  2   Regions            21924 non-null  object
#  3   Nature             21924 non-null  object
#  4   year               21924 non-null  int64
#  5   month              21924 non-null  int64
#  6   day                21924 non-null  int64
#  7   ALLSKY_SFC_SW_DWN  21924 non-null  float64
#  8   CLRSKY_SFC_SW_DWN  21924 non-null  float64
#  9   GWETROOT           21924 non-null  float64
#  10  GWETTOP            21924 non-null  float64
#  11  PRECTOTCORR        21924 non-null  float64
#  12  PS                 21924 non-null  float64
#  13  QV2M               21924 non-null  float64
#  14  RH2M               21924 non-null  float64
#  15  T2M                21924 non-null  float64
#  16  T2M_MAX            21924 non-null  float64
#  17  T2M_MIN            21924 non-null  float64
#  18  T2M_RANGE          21924 non-null  float64
#  19  WD10M              21924 non-null  float64
#  20  WS10M              21924 non-null  float64
#  21  WS2M               21924 non-null  float64
#  22  insee_dep          21924 non-null  int64
# dtypes: float64(16), int64(4), object(3)
# memory usage: 3.8+ MB

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"])

# %%
df["year"] = df["Datetime"].dt.year
df["month"] = df["Datetime"].dt.month
df["dayofweek"] = df["Datetime"].dt.dayofweek  # 0=Mon
df["is_weekend"] = df["dayofweek"].isin([5, 6]).astype(int)

# %%
df[["Consommation","T2M","T2M_MAX","ALLSKY_SFC_SW_DWN","T2M_MIN","PRECTOTCORR","RH2M","WD10M","PS","WS10M"]].describe()
# Out:
#         Consommation           T2M       T2M_MAX  ALLSKY_SFC_SW_DWN  \
# count   21924.000000  21924.000000  21924.000000       21924.000000
# mean   204433.967843     12.013618     16.923766          12.832862
# std     94293.008281      6.930725      7.922475           7.962586
# min     58376.000000     -8.040000     -3.690000           0.460000
# 25%    125892.500000      6.827500     10.920000           5.710000
# 50%    191000.500000     11.635000     16.440000          11.700000
# 75%    262712.500000     17.380000     22.710000          19.062500
# max    624804.000000     33.310000     42.330000          32.360000
#
#             T2M_MIN   PRECTOTCORR          RH2M         WD10M            PS  \
# count  21924.000000  21924.000000  21924.000000  21924.000000  21924.000000
# mean       7.537540      1.994065     79.303629    195.470799     98.300271
# std        6.030541      3.699876     13.039571    100.094157      2.955280
# min      -12.570000      0.000000     23.680000      0.000000     87.760000
# 25%        3.100000      0.030000     71.980000    114.200000     97.290000
# 50%        7.570000      0.360000     81.770000    213.300000     99.140000
# 75%       12.170000      2.350000     89.630000    274.300000    100.330000
# max       24.850000     53.790000    100.000000    360.000000    103.610000
#
#               WS10M
# count  21924.000000
# mean       4.279693
# std        1.967521
# min        0.620000
# 25%        2.820000
# 50%        3.890000
# 75%        5.340000
# max       15.030000

# %% [markdown]
# #### Commentaire

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Daily trend

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, x="Datetime", y="Consommation", color='blue')
plt.title("Daily Electricity Consumption")
plt.xlabel("Date")
plt.ylabel("Consumption (MWh)")
plt.show()

# %%
monthly_avg = df.groupby("month")["Consommation"].mean()
plt.figure(figsize=(8,4))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values, color="royalblue")
plt.title("Average Electricity Consumption by Month")
plt.xlabel("Month")
plt.ylabel("Average Consumption (MWh)")
plt.show()

# %% [markdown]
# ### Relationship between temperature and consumption

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df,x="T2M",y=np.log(df["Consommation"]),alpha = 0.4)
plt.title("Electricity vs Temperature")
plt.xlabel("Temperature celsius")
plt.ylabel("Electricity consommation in Mwh")
plt.show()

# %% [markdown]
# ### Regional comparison

# %%
# plt.figure(figsize=(10,5))
# region_mean = df.groupby("Regions")["Consommation"].mean().sort_values(ascending=False)
# sns.barplot(x=region_mean.index, y=region_mean.values, palette="viridis")
# plt.xticks(rotation=45)
# plt.title("Average Consumption by Regions")
# plt.ylabel("Mean Daily Consumption Mwh")
# plt.xlabel("Regions in France")
# plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="T2M", y=np.log(df["Consommation"]), hue="Regions", data=df, alpha=0.5)
plt.title("Temperature vs Consumption by Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Solar Radiation and Consommation

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df, x ="ALLSKY_SFC_SW_DWN", y = np.log(df["Consommation"]), alpha = 0.4)
plt.title("Solar Radiation and consommation")
plt.xlabel("Solar Radiation")
plt.ylabel("Consommation electricity")
plt.show()

# %% [markdown]
# ### Humidity vs consommation

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df, x ="RH2M", y = np.log(df["Consommation"]), alpha = 0.4)
plt.title("Humidity and consommation")
plt.xlabel("Humidity")
plt.ylabel("Consommation electricity")
plt.show()

# %%
labels = {
    "T2M": "Temperature (°C)",
    "RH2M": "Humidity (%)",
    "WS10M": "Wind Speed (m/s)",
    "ALLSKY_SFC_SW_DWN": "Solar Radiation (W/m²)",
    "PRECTOTCORR": "Precipitation (mm/day)",
    "PS":"Pressure"
}

# %%
weather_vars = ["T2M", "RH2M", "WS10M", "ALLSKY_SFC_SW_DWN", "PRECTOTCORR","PS"]
plt.figure(figsize=(15, 10))

for i, var in enumerate(weather_vars, 1):
    plt.subplot(2, 3, i)
    sns.scatterplot(data=df, x=var, y="Consommation", alpha=0.4, color='blue')
    plt.title(f"{var} vs Consommation)")
    plt.xlabel(labels.get(var, var))
    plt.ylabel("Consumption (MWh)")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))

for i, var in enumerate(weather_vars, 1):
    plt.subplot(2, 3, i)
    corr = df["Consommation"].corr(df[var])
    
    sns.scatterplot(data=df, x=var, y="Consommation", alpha=0.4, color='blue')
    sns.regplot(data=df, x=var, y="Consommation", scatter=False, color='red')
    
    plt.title(f"{var} vs Consommation\n(r = {corr:.2f})")
    plt.xlabel(labels.get(var, var))
    plt.ylabel("Consumption (MWh)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional comparison

# %% [markdown]
# ### Mean comparison by regions

# %%
region_mean = df.groupby("Regions")["Consommation"].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=region_mean.values, y=region_mean.index, palette="viridis")
plt.title("Average Electricity Consumption by Region")
plt.xlabel("Mean Consumption (MWh)")
plt.ylabel("Region")
plt.show()
# Out:
# /tmp/ipykernel_3059/1455838715.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_mean.values, y=region_mean.index, palette="viridis")

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="Regions", y="T2M", palette="coolwarm")
plt.title("Temperature Distribution by Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_3059/2395323793.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Regions", y="T2M", palette="coolwarm")

# %%
sns.pairplot(df[['Consommation', 'T2M', 'RH2M', 'WS10M', 'ALLSKY_SFC_SW_DWN']], diag_kind='kde')
plt.suptitle("Pairwise Relationships among Key Variables", y=1.02)
plt.show()

# %% [markdown]
# ### Correlation heatmap

# %%
plt.figure(figsize=(10,8))
corr = df[['Consommation','T2M','T2M_MAX','T2M_MIN','RH2M','ALLSKY_SFC_SW_DWN','WS10M','PRECTOTCORR',"PS"]].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation between Electricity Consumption and Weather Variables")
plt.show()

# %%
# %pip install geopandas shapely ipywidgets cartiflette
# Out:
# Requirement already satisfied: geopandas in /home/onyxia/work/.env/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: shapely in /home/onyxia/work/.env/lib/python3.13/site-packages (2.1.2)
# Requirement already satisfied: ipywidgets in /home/onyxia/work/.env/lib/python3.13/site-packages (8.1.8)
# Requirement already satisfied: cartiflette in /home/onyxia/work/.env/lib/python3.13/site-packages (0.1.9)
# Requirement already satisfied: numpy>=1.24 in /home/onyxia/work/.env/lib/python3.13/site-packages (from geopandas) (2.3.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /home/onyxia/work/.env/lib/python3.13/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: comm>=0.1.3 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipywidgets) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: platformdirs>=4.3.6 in /home/onyxia/work/.env/lib/python3.13/site-packages (from cartiflette) (4.5.0)
# Requirement already satisfied: requests-cache>=1.2.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from cartiflette) (1.2.1)
# Requirement already satisfied: requests>=2.32.3 in /home/onyxia/work/.env/lib/python3.13/site-packages (from cartiflette) (2.32.5)
# Requirement already satisfied: tqdm>=4.67.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from cartiflette) (4.67.1)
# Requirement already satisfied: decorator>=4.3.2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/onyxia/work/.env/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/onyxia/work/.env/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/onyxia/work/.env/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/onyxia/work/.env/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: certifi in /home/onyxia/work/.env/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /home/onyxia/work/.env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests>=2.32.3->cartiflette) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests>=2.32.3->cartiflette) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests>=2.32.3->cartiflette) (2.5.0)
# Requirement already satisfied: attrs>=21.2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests-cache>=1.2.1->cartiflette) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests-cache>=1.2.1->cartiflette) (25.3.0)
# Requirement already satisfied: url-normalize>=1.4 in /home/onyxia/work/.env/lib/python3.13/site-packages (from requests-cache>=1.2.1->cartiflette) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from cattrs>=22.2->requests-cache>=1.2.1->cartiflette) (4.15.0)
# Requirement already satisfied: executing>=1.2.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/onyxia/work/.env/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/onyxia/work/.env/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
model_idf, results_idf = analyze_region_regression(df, "Île-de-France", features=['T2M'])
if results_idf:
    plot_regression_results("Île-de-France", results_idf)

features_list = ['T2M', 'ALLSKY_SFC_SW_DWN', 'RH2M', 'is_weekend']
model_multi, results_multi = analyze_region_regression(df, "Île-de-France", features=features_list)
if results_multi:
    plot_regression_results("Île-de-France (Multi-var)", results_multi)
